# %%
import os
os.getcwd()
# Out:
# 'C:\\projects\\chart_scrape\\notebooks'

# %%
import glob
filelist = glob.glob('C:\projects\chart_scrape\downloads\Scatter plot/*')
print(len(filelist))
# Out:
# 704

# %%
import numpy as np
from PIL import Image
img=[]
for fname in filelist:
    img.append(np.array(cv2.resize(cv2.imread(fname),(256,256))))

# %%
img = np.array(img)

# %%
img.shape
# Out:
# (704, 256, 256, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# im = np.array(Image.open('image.jpg'))

plt.imshow(img[703])
plt.show()

# %%
# os.getcwd()

# %%
# print(Image.open(filelist[0]))

# %%
# import pickle
# pickle.dump( np.array(x), filehandle, protocol=2 )

# %%
np.save("scatter", img, allow_pickle=True, fix_imports=True)

# %%
os.getcwd()
# Out:
# 'C:\\projects\\chart_scrape\\notebooks'
