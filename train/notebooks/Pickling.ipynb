# %%
import os
import numpy as np
from PIL import Image
import cv2

os.getcwd()
# Out:
# 'C:\\projects\\chart_scrape\\notebooks'

# %%
# import glob
# filelist = glob.glob('C:\projects\figureqa\train1\segregated\line/*')
# # print(len(filelist))

# %%
print(os.listdir('C:\\projects\\figureqa\\train1\\segregated\\'))
dirs = os.listdir('C:\\projects\\figureqa\\train1\\segregated\\')
# Out:
# ['dot_line', 'hbar_categorical', 'line', 'pie', 'vbar_categorical']

# %%
CATS  =  {'dot_line':0, 'hbar_categorical' : 1, 'line': 2, 'pie' :3, 'vbar_categorical' : 4}
print(CATS)
# Out:
# {'dot_line': 0, 'hbar_categorical': 1, 'line': 2, 'pie': 3, 'vbar_categorical': 4}

# %%
 del(img, Ytrain)

# %%
img= []
for i in dirs:
    path = 'C:\\projects\\figureqa\\train1\\segregated\\'+ i +'\\'
    files = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if '.txt' in file:
                files.append(os.path.join(r, file))


    print(CATS[i])
    try:
        Ytrain = np.append(Ytrain, np.repeat(CATS[i] , len(f)))
    except Exception as ex:
        print(ex)
        Ytrain = np.repeat(CATS[i] , len(f))
    print(Ytrain.shape)    
    
    
    print(len(f))
    for fnames in f:
        fname = path + fnames
#         print(fname)
        img.append(np.array(cv2.resize(cv2.imread(fname),(256,256))))
# Out:
# 0
# name 'Ytrain' is not defined
# (4000,)
# 4000
# C:\projects\figureqa\train1\segregated\dot_line\10.png
# C:\projects\figureqa\train1\segregated\dot_line\10003.png
# C:\projects\figureqa\train1\segregated\dot_line\10007.png
# C:\projects\figureqa\train1\segregated\dot_line\10011.png
# C:\projects\figureqa\train1\segregated\dot_line\10016.png
# C:\projects\figureqa\train1\segregated\dot_line\10018.png
# C:\projects\figureqa\train1\segregated\dot_line\10028.png
# C:\projects\figureqa\train1\segregated\dot_line\1003.png
# C:\projects\figureqa\train1\segregated\dot_line\10036.png
# C:\projects\figureqa\train1\segregated\dot_line\10037.png
# C:\projects\figureqa\train1\segregated\dot_line\10048.png
# C:\projects\figureqa\train1\segregated\dot_line\10079.png
# C:\projects\figureqa\train1\segregated\dot_line\1008.png
# C:\projects\figureqa\train1\segregated\dot_line\1009.png
# C:\projects\figureqa\train1\segregated\dot_line\10096.png
# ...

# %%
#

# %%
# del(Ytrain)

# %%
print(Ytrain[250])
print(Ytrain[4500])
print(Ytrain[9500])
print(Ytrain[13500])
print(Ytrain[17050])
# print(Ytrain[20050])



plt.imshow(img[250])
plt.show()
plt.imshow(img[7500])
plt.show()
plt.imshow(img[9500])
plt.show()
plt.imshow(img[13500])
plt.show()

plt.imshow(img[17051])
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# import os

# path = 'C:\\projects\\figureqa\\train1\\segregated\\line\\'

# files = []
# # r=root, d=directories, f = files
# for r, d, f in os.walk(path):
#     for file in f:
#         if '.txt' in file:
#             files.append(os.path.join(r, file))

# for f in files:
#     print(f)

# %%
# f
# Out:
# ['100.png',
#  '10001.png',
#  '10002.png',
#  '10006.png',
#  '1001.png',
#  '10015.png',
#  '10019.png',
#  '10020.png',
#  '10021.png',
#  '10025.png',
#  '10034.png',
#  '10044.png',
#  '10045.png',
#  '10046.png',
#  '10051.png',
#  '10053.png',
#  '10054.png',
#  '10059.png',
#  '1006.png',
#  '10066.png',
#  '10067.png',
#  '10075.png',
#  '10076.png',
#  '10078.png',
#  '10080.png',
#  '10088.png',
#  '10090.png',
#  '10094.png',
#  '10095.png',
#  '10099.png',
#  '10105.png',
#  '10111.png',
#  '10114.png',
#  '10116.png',
#  '10121.png',
#  '10122.png',
#  '10129.png',
#  '10130.png',
#  '10132.png',
#  '10144.png',
#  '10147.png',
#  '10151.png',
#  '1016.png',
#  '10160.png',
#  '10168.png',
#  '10169.png',
#  '1017.png',
#  '10170.png',
#  '10176.png',
#  '10179.png',
#  '10180.png',
#  '10186.png',
#  '10187.png',
#  '1019.png',
#  '10197.png',
#  '10199.png',
#  '1020.png',
#  '10202.png',
#  '10203.png',
#  '10204.png',
#  '10207.png',
#  '10210.png',
#  '10212.png',
# ...

# %%
# import numpy as np
# from PIL import Image
# import cv2
# img=[]
# for fname in filelist:
#     img.append(np.array(cv2.resize(cv2.imread(fname),(256,256))))

# %%
img = np.array(img)

# %%
img.shape
# Out:
# (20000, 256, 256, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# im = np.array(Image.open('image.jpg'))

plt.imshow(img[7401])
plt.show()
print(Ytrain[74])
# Out:
# 0

# %%
# os.getcwd()

# %%
# print(Image.open(filelist[0]))

# %%
# import pickle
# pickle.dump( np.array(x), filehandle, protocol=2 )

# %%
np.save("..\\data\\google_scrape\\Map", img, allow_pickle=True, fix_imports=True)

# %%
os.getcwd()
# Out:
# 'C:\\projects\\chart_scrape\\notebooks'
