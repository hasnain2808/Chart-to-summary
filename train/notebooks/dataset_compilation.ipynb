# %%
import os
import numpy as np

# %%
# print(os.getcwd())
labels2 = os.listdir(os.getcwd() + '\\..\\data\\google_scrape')

labels = ['AreaGraph.npy', 'BarGraph.npy',
          'LineGraph.npy',
          'PieChart.npy', 'ScatterGraph.npy']
print(labels)
# Out:
# ['AreaGraph.npy', 'BarGraph.npy', 'LineGraph.npy', 'PieChart.npy', 'ScatterGraph.npy']

# %%
# dataX=np.array()

# %%
j=0
for i in labels:
    if j == 0:
        dataX = np.load('C:\\projects\\chart_scrape\\tr\\data\\google_scrape\\' + i)
        dataY = np.array(np.repeat(i.split('.')[0],dataX.shape[0]))
        j=j+1
        
        
        temp =  np.load('C:\\projects\\chart_scrape\\tr\\data\\revision\\' + i)
        tempy = np.array(np.repeat(i.split('.')[0],temp.shape[0]))
        dataY = np.concatenate((dataY,tempy))
        dataX = np.concatenate((dataX,temp))
        j=j+1
        

    else:
        temp =  np.load('C:\\projects\\chart_scrape\\tr\\data\\google_scrape\\' + i)
        tempy = np.array(np.repeat(i.split('.')[0],temp.shape[0]))
        dataY = np.concatenate((dataY,tempy))
        dataX = np.concatenate((dataX,temp))
        j=j+1        
        temp =  np.load('C:\\projects\\chart_scrape\\tr\\data\\revision\\' + i)
        tempy = np.array(np.repeat(i.split('.')[0],temp.shape[0]))
        dataY = np.concatenate((dataY,tempy))
        dataX = np.concatenate((dataX,temp))
        j=j+1

# %%
print(dataX.shape,dataY.shape)
# Out:
# (1903, 256, 256, 3) (1903,)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# im = np.array(Image.open('image.jpg'))
print(dataY[45])
plt.imshow(dataX[45])
plt.show()
# Out:
# AreaGraph

# %%
# data.shape

# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import os
import ast
import datetime as dt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]
plt.rcParams['font.size'] = 14
import seaborn as sns
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.inception_v3 import InceptionV3
#from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.applications.inception_v3 import preprocess_input

# start = dt.datetime.now()

# %%
from sklearn.utils import shuffle

X, y = shuffle(dataX, dataY, random_state=0)

# %%
for i in range(0,10):
# from sklearn.utils import shuffle
    X, y = shuffle(X, y, random_state=0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random

# im = np.array(Image.open('image.jpg'))
for i in random.sample(range(0, 1903), 25):
    print(y[i])
    plt.imshow(X[i])
    plt.show()
# Out:
# PieChart
# ScatterGraph
# LineGraph
# LineGraph
# BarGraph
# AreaGraph
# BarGraph
# ScatterGraph
# ScatterGraph
# AreaGraph
# ScatterGraph
# ScatterGraph
# PieChart
# PieChart
# LineGraph
# LineGraph
# BarGraph
# BarGraph
# ScatterGraph
# BarGraph
# LineGraph
# LineGraph
# BarGraph
# AreaGraph
# LineGraph

# %%
Xtestn=X[1500:]
ytestn=y[1500:]

# %%
Xtestn.shape
ytestn.shape
# Out:
# (403, 256, 256, 3)
# (403,)

# %%
# Xvalid = Xtest[0:250].shape
# yvalid = ytest[0:250].shape

# %%
Xvalidn = Xtestn[0:250]
yvalidn = ytestn[0:250]

# %%
Xtestn = Xtestn[250:]
ytestn = ytestn[250:]

# %%
Xtrainn = X[:1500]
ytrainn = y[:1500]

# %%
print(Xvalidn.shape,yvalidn.shape,Xtestn.shape,ytestn.shape,Xtrainn.shape, ytrainn.shape )
# Out:
# (250, 256, 256, 3) (250,) (153, 256, 256, 3) (153,) (1500, 256, 256, 3) (1500,)

# %%
dataset = (Xtrainn, ytrainn,Xvalidn,yvalidn,Xtestn,ytestn)
dataset_names = ('Xtrainn', 'ytrainn','Xvalidn','yvalidn','Xtestn','ytestn')

# %%
for i in range(0,6):
    np.save("C:\\projects\\chart_scrape\\tr\\data\\dataset\\" + dataset_names[i], dataset[i], allow_pickle=True, fix_imports=True)

# %%
labels = os.listdir('C:\\projects\\chart_scrape\\tr\\data\\dataset')

# %%
for i in labels:
    print(i,np.load('C:\\projects\\chart_scrape\\tr\\data\\dataset\\' + i).shape)
# Out:
# Xtest.npy (730, 256, 256, 3)
# Xtestn.npy (153, 256, 256, 3)
# Xtrain.npy (2183, 256, 256, 3)
# Xtrainn.npy (1500, 256, 256, 3)
# Xvalid.npy (730, 256, 256, 3)
# Xvalidn.npy (250, 256, 256, 3)
# ytest.npy (730,)
# ytestn.npy (153,)
# ytrain.npy (2183,)
# ytrainn.npy (1500,)
# yvalid.npy (730,)
# yvalidn.npy (250,)
